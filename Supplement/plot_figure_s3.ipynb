# %% [markdown]
# This notebook plots Supplemental Figure 3

# %%
import numpy as np
import scanpy as sc
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
color_map = LinearSegmentedColormap.from_list('ss2_to_10x', ['lightgrey', 'red', 'darkred'])

# %%
# Read data

# %%
df_ann = pd.read_csv('df_annotation_all_bat.csv',index_col = 0)

# %%
adata_atlas = sc.read('./adata_umap_pca.h5')

# %%
# Plot Supplemental Figure 3

plt.figure(figsize=(6,6),dpi=300)


list_b3 = np.array(df_ann[df_ann.index.str.startswith('SIGAB3')]['closest.cell'])
list_a3 = np.array(df_ann[df_ann.index.str.startswith('SIGAA3')]['closest.cell'])

plt.scatter(adata_atlas.obsm['X_umap'][:,0], adata_atlas.obsm['X_umap'][:,1], c = [0.8,0.8,0.8], s = 0.2)
plt.scatter(adata_atlas[list_b3].obsm['X_umap'][:,0], adata_atlas[lista].obsm['X_umap'][:,1], c = 'k', s = 2)
plt.scatter(adata_atlas[list_a3].obsm['X_umap'][:,0], adata_atlas[listaa].obsm['X_umap'][:,1], c = 'r', s = 0.3)

plt.axis('off')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# (-13.778090792886001, 11.9804241254172, -16.30468076650914, 19.40359188056074)
